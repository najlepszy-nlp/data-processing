# %%
import pandas as pd
import jsonlines
import math
import word2number.w2n

# %% [markdown]
# ### Load Expected Data

# %%
orig_expected_df = pd.read_csv('../data/expected.csv', delimiter=';')

# %%
expected_df = orig_expected_df[[
    "<primary_vehicle_involved>",
    "<secondary_vehicle_involved>",
    "<tertiary_vehicle_involved>",
    "<any_more_vehicles_involved>",
    "<url>", 
    "<available_ages_of_the_deceased>", 
    "<total_number_of_people_injured>",
    "<is_reason_or_cause_for_the_accident_ploughed_or_ram_or_hit_or_collision_or_breakfail_or_others>",
    "<total_number_of_people_killed>",
    "<accident_datetime_from_url>",
    "<day_of_the_week_of_the_accident>",
    "<location metadata>",
]].rename(columns={
    "<url>": "url", 
    "<available_ages_of_the_deceased>": "expectedAgeOfCasualties", 
    "<total_number_of_people_injured>": "expectedInjuries",
    "<is_reason_or_cause_for_the_accident_ploughed_or_ram_or_hit_or_collision_or_breakfail_or_others>": "expectedReason",
    "<total_number_of_people_killed>": "expectedCasualties",
    "<accident_datetime_from_url>": "expectedDate",
    "<day_of_the_week_of_the_accident>": "expectedDayOfWeek",
    "<location metadata>": "expectedPlace",
})

def combine_vehicles(row):
    vehicles = []
    if pd.notna(row['<primary_vehicle_involved>']):
        vehicles.append(row['<primary_vehicle_involved>'])
    if pd.notna(row['<secondary_vehicle_involved>']):
        vehicles.append(row['<secondary_vehicle_involved>'])
    if pd.notna(row['<tertiary_vehicle_involved>']):
        vehicles.append(row['<tertiary_vehicle_involved>'])
    if pd.notna(row['<any_more_vehicles_involved>']):
        vehicles.append(row['<any_more_vehicles_involved>'])

    return vehicles

expected_df['expectedVehicles'] = expected_df.apply(combine_vehicles, axis=1)

def clean_vehicles(vehicles):
    return [vehicle.replace(">", "").replace("<", "").lower() for vehicle in vehicles]

expected_df['expectedVehicles'] = expected_df['expectedVehicles'].apply(clean_vehicles)

expected_df = expected_df.drop(columns=[
    "<primary_vehicle_involved>",
    "<secondary_vehicle_involved>",
    "<tertiary_vehicle_involved>",
    "<any_more_vehicles_involved>",
])

expected_df['url'] = expected_df['url'].apply(lambda x: (x.replace(">", "").replace("<", ""))).astype(str)
expected_df = expected_df.drop_duplicates(['url'])

print(expected_df.shape)
expected_df.head()
# Out:
# (1670, 9)
#                                                  url expectedAgeOfCasualties  \
# 0  https://www.unb.com.bd/category/Bangladesh/tru...                     NaN
# 1  https://www.unb.com.bd/category/Bangladesh/2-k...                     NaN
# 2  https://www.unb.com.bd/category/Bangladesh/fou...          <(45, 32, 34)>
# 3  https://www.unb.com.bd/category/Bangladesh/kar...              <(60, 55)>
# 4  https://www.unb.com.bd/category/Bangladesh/tou...                    <32>
#
#   expectedInjuries expectedReason expectedCasualties      expectedDate  \
# 0              <0>    <collision>                <3>  <20221008 01:02>
# 1              <4>    <collision>                <2>  <20221012 12:24>
# 2              <0>    <collision>                <4>  <20221015 10:25>
# 3              <0>      <capsize>                <7>  <20221015 15:02>
# 4              <6>    <collision>                <1>  <20221019 18:12>
#
#   expectedDayOfWeek expectedPlace                   expectedVehicles
# 0          <Friday>     <Jashore>                [truck, motorcycle]
# 1       <Wednesday>      <N’ganj>                         [bus, cng]
# 2        <Saturday>     <Gazipur>  [cycle van, bus, bus, pedestrian]
# 3         <Tuesday>  <Chattogram>                          [trawler]
# 4       <Wednesday>   <Rangamati>                     [chander gari]

# %% [markdown]
# ### Load Processed Data

# %%
data: list[dict] = []

with jsonlines.open("../data/data_processed.jsonl") as reader:
    data = list(reader.iter())

filtered_data = list(map(
    lambda x: {
        "url" : x["url"],
        "ageOfCasualties": x["ageOfCasualties"],
        "injuries": x["injuries"],
        "reason": x["reason"],
        "vehicles": x["vehicles"],
        "casualties": x["casualties"],
        "date": x["date"],
        "place": x["place"]["name"],
    }, 
    data,
))

processed_df = pd.DataFrame(filtered_data)
processed_df["url"] = processed_df["url"].astype(str)
processed_df['vehicles'] = processed_df['vehicles'].apply(clean_vehicles)


print(processed_df.shape)
processed_df.head()
# Out:
# (864, 8)
#                                                  url ageOfCasualties  \
# 0  https://www.unb.com.bd/category/Bangladesh/rec...              []
# 1  https://www.unb.com.bd/category/Bangladesh/out...              []
# 2  https://www.unb.com.bd/category/Bangladesh/3-d...              []
# 3  https://www.unb.com.bd/category/Bangladesh/mot...            [45]
# 4  https://www.unb.com.bd/category/Bangladesh/tee...            [13]
#
#                                        injuries  \
# 0                                       several
# 1                                            10
# 2                                           two
# 3                                          died
# 4  Dhaka Medical College morgue for an autopsy.
#
#                                               reason  \
# 0                                   reckless driving
# 1                       crashed into the other truck
# 2                           battery-run autorickshaw
# 3  Amzad lost control of his motorcycle and fell ...
# 4                                  under the flyover
#
#                                             vehicles  casualties        date  \
# 0                                      [private car]           0        None
# 1  [microbus, dhaka-chattogram highway, goods-lad...           0  2024-02-09
# 2  [battery-run autorickshaw, tangail&ndashbound ...           0  2024-02-19
# 3                                            [truck]           1  2024-01-15
# 4                             [unidentified vehicle]           1  2024-01-04
#
#         place
# 0  chattogram
# 1  chattogram
# 2     gazipur
# 3      bogura
# 4       dhaka

# %% [markdown]
# ### Joined dataframes

# %%
joined_df = processed_df.merge(expected_df, on='url', how='left')
joined_df.shape
# Out:
# (864, 16)

# %% [markdown]
# ### Score on Age Of Casualties

# %%
total = list(joined_df.iterrows()).__len__()
correct = 0

for index, row in joined_df.iterrows():
    try:
        if type(row['expectedAgeOfCasualties']) == float and math.isnan(row["expectedAgeOfCasualties"]) and row["ageOfCasualties"] == []:
            correct += 1
        elif type(row['expectedAgeOfCasualties']) == str and row['expectedAgeOfCasualties'] == "NA":
            if row["ageOfCasualties"] == []:
                correct += 1 
        elif type(row['expectedAgeOfCasualties']) == str and type(eval(row['expectedAgeOfCasualties'].replace(">", "").replace("<", ""))) in (tuple, list):
            if set(eval(row['expectedAgeOfCasualties'].replace(">", "").replace("<", ""))).issubset(set(row["ageOfCasualties"])):
                correct += 1
        elif type(row['expectedAgeOfCasualties']) == str and type(eval(row['expectedAgeOfCasualties'].replace(">", "").replace("<", ""))) == int:
            if eval(row['expectedAgeOfCasualties'].replace(">", "").replace("<", "")) in row["ageOfCasualties"]:
                correct += 1

    except Exception as e:
        pass


print(f"Correct ageOfCasualties: {correct}/{total} ({correct/total*100:.2f}%)")
# Out:
# Correct ageOfCasualties: 244/864 (28.24%)

# %% [markdown]
# ### Score on Injuries

# %%
total = len(joined_df)
correct = 0

for index, row in joined_df.iterrows():
    try:
        expected = int(row['expectedInjuries'].replace(">", "").replace("<", ""))
    except Exception as e:
        continue


    try:
        actual = word2number.w2n.word_to_num(row["injuries"])
    except ValueError:
        actual = 0

    if expected == actual:
        correct += 1

print(f"Correct injuries: {correct}/{total} ({correct/total*100:.2f}%)")
# Out:
# Correct injuries: 382/864 (44.21%)

# %% [markdown]
# ### Score on Reason

# %%
total = len(joined_df)
correct = 0

for index, row in joined_df.iterrows():
    if type(row['expectedReason']) == str and row['expectedReason'].replace(">", "").replace("<", "") in row["reason"]:
        correct += 1

print(f"Correct reason: {correct}/{total} ({correct/total*100:.2f}%)")
# Out:
# Correct reason: 181/864 (20.95%)

# %% [markdown]
# ### Score on Vehicles

# %%
total = len(joined_df)
correct = 0

# for index, row in joined_df.iterrows():
#     print(row['expectedVehicles'], row['vehicles'])
#     if type(row['expectedVehicles']) == list and set(row['expectedVehicles']) == set(row['vehicles']):
#         correct += 1
for index, row in joined_df.iterrows():
    print(row['expectedVehicles'], row['vehicles'])
    if type(row['expectedVehicles']) == list:
        if len(row['expectedVehicles']) == 0:
            if len(row['vehicles']) == 0:
                correct += 1
            continue

        correct_vehicles = sum(expected in vehicle for expected in row['expectedVehicles'] for vehicle in row['vehicles'])
        correct += correct_vehicles / len(row['expectedVehicles'])



print(f"Correct vehicles: {correct}/{total} ({correct/total*100:.2f}%)")
# Out:
# ['car', 'microbus'] ['private car']
# ['truck', '20240209 18:59'] ['microbus', 'dhaka-chattogram highway', 'goods-laden truck']
# ['truck', 'auto rickshaw'] ['battery-run autorickshaw', 'tangail&ndashbound truck']
# ['truck', 'motorcycle'] ['truck']
# ['unknown'] ['unidentified vehicle']
# ['motorcycle'] ['motorcycle']
# ['bus', 'pedestrian'] ['real coach']
# ['car'] ['sport utility vehicle (suv)']
# ['train', 'pedestrian'] ['speedy train']
# ['cng', 'truck'] ['cng autorickshaw', 'truck', 'cng']
# ['bus'] ['dhaka-bound bus', 'bangabandhu expressway']
# ['motorcycle', 'motorcycle'] ['motorcycle']
# ['(truck, mahindra)'] ['sand-laden truck']
# ['motorcycle', 'pickup'] ['pick-up van', 'fish-laden pick-up van']
# ['truck', 'cng', 'shallow engine'] ['truck', 'cng run auto-rickshaw', 'shallow engine', 'cng-run auto-rickshaw']
# ['microbus', 'cng', 'truck', 'truck'] ['dhaka-sylhet highway', 'truck', 'microbus', 'cng-run auto-rickshaw']
# ['truck', 'cng', 'bus'] ['sand-laden truck', 'bus', 'cng-run autorickshaw']
# ['motorcycle', 'bus', 'pedestrian'] ['dhaka-khulna highway', 'khulna-bound bus']
# ['motorcycle', 'truck'] ['motorcycle', 'truck', 'bagerhat-khulna highway']
# ['bus', 'truck'] ['broken-down truck', 'dhaka-mawa expressway', 'dhaka-bound bus', 'broken-down goods carrying truck']
# ['unknown', 'pedestrian'] ['unknown vehicle']
# ['cng', 'bus'] ['bus']
# ['auto rickshaw', 'truck'] ['truck']
# ['truck', 'motorcycle'] ['sand-laden truck']
# ['fire service truck', 'bus', 'car', 'rickshaw'] ['rickshaw', 'bus', 'private car']
# ['microbus', 'cng'] ['cng-run auto-rickshaw', 'microbus', 'cng auto-rickshaw', 'dhaka metro-ch19-7462']
# ['bus', 'pedestrian'] ['dhaka-bound bus']
# ['truck', 'pickup'] ['pickup van', 'sand-carrying truck']
# ['(motorcycle, bus, truck, covered-van, pickup, tractor, trolley, lorry, tanker, private car, microbus, ambulance, three-wheeler, nosimon, karimon, mahindra, brickbhanga machine cars, bicycle, rickshaw)'] ['truck', 'covered-van', 'pickup', 'tractor', 'trolley', 'lorry', 'private car', 'microbus', 'easy bike', 'auto-rickshaw', 'mishuk', 'nosimon-karimon-mahindra-brickbhanga machine cars']
# ['bus'] ['rangpur-bound bus', 'boishakhi paribahan']
# ['bus', 'pedestrian'] ['bus']
# ['bus', 'motorcycle'] ['bus', 'motorbike', 'lovely paribahan']
# ['microbus'] ['microbus', 'dhaka-khulna highway']
# ['unknown'] ['unknown vehicle']
# ['truck', 'truck'] ['bogra-naogaon regional highway', 'dhaka-bogra highway', 'paddy-laden truck']
# ['truck', 'cng'] ['cng-run auto-rickshaw', 'truck']
# ['train'] ['two passenger trains']
# ['tractor', 'motorcycle'] ['tractor', 'motorbike', 'wood-laden tractor']
# ['truck', 'van'] ['truck', 'van']
# ['train'] ['two passenger trains', 'more than a dozen mangled rail cars']
# ['truck', 'pickup'] ['pick-up van', 'stone-laden truck']
# ['pedestrian', '(50)'] ['bus', 'rangpur-bound bus']
# ['truck', 'cng'] ['cng-run auto-rickshaw', 'cng run auto-rickshaw', 'sand-laden truck', 'shyamganj-bound auto-rickshaw']
# ['(bus, bus, motorbike)', '(truck, three-wheeler)'] ['bus', 'bangabandhu expressway', 'truck', 'three-wheeler']
# ['bus', 'pedestrian'] ['welcome paribahan']
# ['truck', 'pickup', 'motorcycle'] ['truck', 'pick-up van', 'motorbike']
# ['bus', 'auto rickshaw'] ['bus', 'tisha paribahan']
# ['bus', 'motorcycle'] ['bus', 'motorbike']
# ['bus', 'truck'] ['bus', 'bangabandhu expressway', 'truck']
# ['motorcycle'] ['motorbike']
# ['bus'] ['dhaka-bound bus', 'emad paribahan']
# ['motorcycle'] []
# ['bus', 'pickup'] ['bus', 'pickup van', 'motorcycle']
# [] []
# ['pickup', 'auto rickshaw', 'pedestrian'] ['pickup van', 'cng-run auto-rickshaw']
# ['bus', 'motorcycle'] ['bus', 'motorbike']
# ['motorcycle', 'nosimon'] []
# [] []
# ['bus', 'other'] ['bus', 'locally-made motorised vehicle']
# ['motorcycle', 'bicycle'] ['motorcycle', 'bicycle']
# ['pickup', 'rickshaw'] ['pickup van']
# ['unkown', 'pedestrian'] ['unknown vehicle']
# ['motorcycle', 'pedestrian'] ['motorbike']
# ['truck', 'motorcycle'] ['truck']
# ['motorcycle'] ['motorbike']
# ['bus', 'motorcycle'] ['motorbike', 'dhaka-bound bus', 'star line paribahan']
# ['bus', 'motorcycle'] ['bus', 'victor paribahan']
# ['bike', 'pedestrian'] ['bike']
# ['train', 'pedestrian'] ['kamalapur-bound train']
# ['truck', 'rickshaw van'] ['truck', 'rickshaw van', 'van']
# ['tanker', 'rickshaw van', 'microbus', 'pedestrian'] ['tanker', 'rickshaw van', 'speeding microbus']
# ['truck', 'motorcycle'] ['truck']
# ['ambulance', 'truck'] ['ambulance', 'truck']
# ['truck', 'motorcycle', 'bus'] ['truck loaded with bricks', 'golden line paribahan']
# ['auto rickshaw', 'motorcycle', 'human hauler'] ['battery-run auto-rickshaw', 'motorbike', 'human hauler']
# ['bus', 'bus'] ['tripti paribahan', 'saimon exclusive paribahan']
# ['bus', 'pedestrian'] ['malanch paribahan']
# ['truck', 'truck'] ['paddy-carrying truck', 'coal-laden truck']
# ['train', 'auto rickshaw'] ['auto-rickshaw']
# ['chander gari'] []
# ['train', 'pedestrian'] ['train']
# ['motorcycle'] ['bike']
# ['microbus', 'pickup', 'truck'] ['truck', 'pick-up', 'microbus']
# ['boat'] ['boat']
# ['20230102 13:28'] []
# ['truck', 'rickshaw van'] ['truck', 'rickshaw van']
# ['motorcycle'] []
# ['boat'] ['boat']
# ['train', 'bus'] ['padma express', 'bus']
# ['vessel', 'vessel'] ['sagar nandini-2']
# ['bus', 'motorcycle', 'unknown'] ['speeding bus', 'unidentified vehicle']
# ['20221221 14:01'] []
# ['truck', 'motorcycle'] ['truck']
# ['bus', 'cng', 'auto rickshaw'] ['bus', 'auto rickshaw']
# ['motorcycle', 'trolley'] ['motorcycle', 'trolley']
# ['(bus,tractor,other)', 'auto rickshaw', 'tractor'] ['dhaka-bound bus', 'aman paribahan', 'auto-rickshaw', 'motorbike']
# ['truck', 'cng'] ['truck loaded with sand', 'cng-run auto-rickshaw']
# ['truck', 'motorcycle'] ['truck']
# ['covered van'] ['covered van']
# ['motorcycle'] ['two-wheeler']
# ['motorcycle', 'motorcycle'] ['monikotha-bound motorcycle', 'sadarpur-bound two-wheeler']
# ['motorcycle', 'motorcycle'] ['motorcycle']
# ['truck', 'motorcycle'] ['truck', 'motorbike']
# ['covered van', 'cng'] ['covered van', 'cng-run auto-rickshaw']
# ['truck', 'motorcycle'] ['truck']
# ['bus', 'cng'] ['cng-run auto-rickshaw']
# ['bus'] ['picnic bus']
# ['covered van', 'motorcycle'] ['covered van']
# ['motorcycle'] ['motorcycle', 'motorbike']
# ['covered van', 'motorcycle'] ['covered van', 'motorbike']
# ['cng', 'bus'] ['cng-run auto rickshaw', 'bus', 'auto rickshaw']
# ['truck', 'pickup', 'pedestrian', 'pedestrian'] ['pickup van', 'passenger bus', 'raida paribahan']
# ['bus', 'covered van'] ['covered van', 'dhaka-chattogram highway', 'bus']
# ['bus', 'motorcycle'] ['bus', 'lalpur-bound passenger bus']
# [] []
# [] []
# ['chander gari'] ['chander gari']
# ['truck'] ['truck']
# [] ['covered van']
# ['cycle van', 'bus', 'bus', 'pedestrian'] ['cycle van']
# ['trawler'] []
# ['boat', '(20,20),20221106 13:06'] ['passenger carrying speedboat', 'goods-laden boat', 'passenger carrying boat']
# ['bus', 'cng'] ['speedy bus', 'cng-run auto-rickshaw', 'narsingdi-bound &lsquobadhan paribahan&rsquo bus']
# ['van', 'car', 'rickshaw', '(cng,bus,truck)'] ['covered van', 'cng-run auto-rickshaw', 'dhaka-bound lorry']
# [] []
# ['train', 'car'] []
# ['bus', 'car'] ['mongla-bound bus', 'didar paribahan']
# ['pedestrian', 'truck', 'car'] ['truck']
# ['train'] ['rohanpur-bound commuter train']
# ['bus'] ['three-wheeler', 'battery-run three-wheeler']
# [] []
# ['truck', 'motorcycle'] ['truck', 'motorcycle']
# [] []
# ['bus', 'van'] ['tricycle van', 'bus', 'van']
# ['van', 'cng', 'car', 'rickshaw'] ['pick-up van', 'cng-run auto-rickshaw']
# ['truck', 'car', 'rickshaw', 'cng'] ['truck', 'cng-run auto-rickshaw', 'cox’s bazar-bound truck']
# [] []
# ['bus', 'construction vehicle'] ['excavator', 'dhaka-bound bus']
# ['bus'] []
# ['car', 'other'] ['unknown vehicle']
# ['motorcycle'] ['motorcycle']
# ['truck', 'motorcycle'] ['speeding truck', 'khulna-bound truck']
# ['truck', '(11,42),20220823 12:20'] ['speeding truck']
# ['truck', 'van', 'car'] ['truck']
# ['(23,21,21),20220826 16:28'] ['private car']
# ['construction vehicle', 'car', 'bus', 'truck'] ['car']
# [] ['seven fire tenders']
# [] []
# ['motorcycle', 'car'] []
# [] []
# ['car', 'rickshaw', 'truck'] ['auto-rickshaw', 'truck']
# [] []
# [] []
# ['bus', 'car', 'construction vehicle'] ['private car']
# ['microbus', '(21)'] ['microbus']
# [] []
# ['motorcycle', 'bus', 'human hauler'] ['taj paribahan&rsquos bus']
# ['bus'] ['bus']
# ['truck'] ['speeding truck', 'truck']
# ['truck', 'van', 'microbus', 'rickshaw'] ['truck', 'covered van', 'dhaka-sylhet highway']
# ['bus', 'human hauler'] ['bus', 'human hauler', 'laguna']
# ['bus'] []
# ['bus'] ['bus', 'khulna-bound bus']
# ['truck', 'car'] ['goods-laden lorry', 'freight truck']
# ['construction vehicle'] ['crane', 'fire tender']
# ['truck', 'motorcycle', 'car'] ['truck']
# ['bus'] ['shadapathor poribohon']
# [] ['feni-laxmipur regional highway']
# ['motorcycle', 'bus'] ['motorcycles']
# ['rickshaw', 'auto rickshaw', 'car', 'bus'] ['anonymous vehicle']
# ['truck', 'car', 'cng', 'rickshaw'] ['truck', 'cng autorickshaw']
# ['train', 'car'] ['concrete mixer three-wheeler', 'tungipara express']
# ['truck', 'bus', 'microbus'] ['dhaka-bound truck', 'sylhet-bound bus and microbus', 'dhaka-sylhet highway']
# ['train'] ['train', 'upakul express']
# ['(35,26,2),20220716 19:28'] ['mymenshingh-bound truck']
# ['tractor', 'trolley', 'car', '(truck,cng,auto rickshaw,rickshaw)'] ['tractor trolley', 'lorry', 'cng-run auto rickshaw']
# ['(35,26,2),20220718 15:40'] ['speeding mymenshingh-bound truck']
# ['bus', 'motorcycle'] ['bus', 'motorcycle']
# ['truck'] ['truck']
# ['bus', 'truck', 'motorcycle'] ['binimoy paribahan’ bus']
# ['motorcycle', 'pedestrian'] ['speeding two-wheeler']
# ['motorcycle', 'car'] ['private car', 'motor bike']
# ['bike', 'bus ', 'na '] ['bike', 'bus', 'dhaka-bound bus', 'cng-run auto-rickshaw', 'van', 'three-wheel van']
# ['motorcycle', 'truck'] ['speeding truck']
# ['train'] ['speeding train', 'freight train']
# ['(22,24,23),20220713 12:59'] ['car', 'panchagarh-rangpur highway']
# [] []
# ['bus', '(20)'] ['bus', 'saudia paribahan']
# [] ['bus']
# [] []
# ['truck', 'motorcycle ', 'na ', 'na '] ['truck']
# ['motorcycle'] ['buses', 'trucks', 'private cars', 'motorbikes', 'ambulances']
# ['truck', 'car'] ['onion-laden truck']
# ['truck', 'motorcycle ', 'na '] ['truck', 'motorcycle']
# ['truck', 'cng'] ['truck', 'cng-run auto-rickshaw', 'cng run auto-rickshaw']
# [] []
# ['train'] ['karnafuli express']
# ['truck'] ['three cargo trucks']
# ['bus', 'van', 'truck', 'microbus'] ['prison van', 'bus']
# [] []
# ['motorcycle', 'tractor', 'trolley'] ['tractor trolley', 'soil-laden tractor-trolley']
# ['bus', 'motorcycle', 'truck'] ['bus']
# ['motorcycle'] ['motorcycle']
# ['truck', 'van ', 'na '] ['truck']
# ['autorickshaw', 'lorry ', 'na '] ['cng-run auto-rickshaw', 'lorry', 'brick-laden truck', 'tractor-trolley', 'paddy-laden tractor-trolley']
# ['motorcycle ', 'na ', 'na '] ['mini passenger vehicle', 'leguna', 'microbus']
# ['other', 'van'] ['covered van', 'motorbike']
# ['bus'] ['ahsan paribahan']
# ['other', 'bus'] ['bus', 'welcome paribahan']
# ['motorcycle'] []
# ['bus', 'van'] ['prison van']
# ['other'] ['unidentified vehicle']
# ['bus'] ['thikana paribahan']
# ['motorcycle'] ['bike']
# ['train', 'van'] ['pick-up van']
# ['(car,truck)', '(van,motorcycle)'] ['cycle van']
# ['other'] ['unidentified vehicle']
# ['van ', 'na ', 'na ', 'na '] ['pickup van']
# ['car ', 'na ', 'na '] ['car']
# ['motorcycle'] ['bike']
# ['lorry', 'motorcycle'] ['lorry', 'truck']
# ['truck', 'truck'] ['corn- laden truck']
# ['bus', 'motorcycle'] ['bandarban-bound bus']
# ['train'] ['train', 'barabkunda shuklalhat rail track']
# ['van', 'other'] ['van']
# ['motorcycle', 'truck'] ['truck']
# ['lorry', 'other'] ['lorry']
# ['truck', 'bicycle'] ['truck', 'soil-laden truck']
# ['other'] ['speeding vehicle', 'unknown vehicle']
# ['car'] ['private car']
# ['truck', 'van'] ['speedy truck']
# ['other', 'truck'] ['bike', 'truck']
# ['train'] ['train', 'kumarkhali rail bridge']
# ['train'] ['panchagarh-bound kanchan express']
# ['car', 'autorickshaw ', 'na '] ['private car', 'cng-run auto rickshaw']
# ['truck', 'autorickshaw ', 'na '] ['truck', 'autorickshaw']
# ['truck'] ['truck', 'feni-noakhali road']
# ['rickshaw'] ['cng-run auto-rickshaw', 'auto-rickshaw']
# ['vehicle ', 'na ', 'na ', 'na '] ['vehicle']
# ['car', 'train ', 'na ', 'na '] ['kurigram express', 'private car']
# ['truck', 'auto rickshaw'] ['speeding truck', 'cng-run auto-rickshaw']
# ['truck', 'bicycle'] ['truck', 'speeding vehicle']
# ['train'] ['benapole-bound train']
# ['motorcycle', 'pedestrian ', 'na ', 'na '] ['bike']
# ['bus ', 'na ', 'na '] ['bus']
# ['bus', 'pedestrian', 'bus '] ['ajmeri paribahan']
# ['microbus'] ['microbus']
# ['train', 'auto rickshaw'] ['auto-rickshaw', 'chilahati-bound simanta express', 'battery-run three wheeler', 'chattogram-bound udayan express']
# ['bus'] ['green bangla paribahan bus']
# ['train'] ['train']
# ['bus', 'auto rickshaw'] ['cng-run auto-rickshaw', 'rangpur-bound hanif paribahan bus']
# ['bus', 'auto rickshaw'] ['dhaka-bound bus', 'battery-run auto-rickshaw']
# ['truck'] ['cement-laden truck']
# ['other', 'van'] ['pickup van', 'dhaka-sylhet highway', 'habiganj-bound motorcycle']
# ['(truck,van,motorcycle)', 'three-wheeler'] ['truck', 'paddy-laden van', 'motorcycle', 'three-wheeler']
# ['bus'] ['bus']
# [] []
# ['bus'] ['jashore-khulna highway', 'rupsha paribahan']
# ['truck', 'motorcycle'] ['goods-laden truck']
# ['motorcycle', 'truck'] ['truck', 'motorcycle']
# ['truck', 'motorcycle'] ['motorcycle', 'truck']
# ['car ', 'na ', 'na '] ['private car', 'dhaka-chattogram highway']
# ['bus', 'truck', 'van'] ['bus', 'truck', 'van', 'rajshahi-bound night coach']
# ['bus', 'truck'] ['bus', 'truck', 'amchattar-belpukur bypass road', 'natore-bound bus', 'rajshahi-bound truck']
# ['bus', 'auto rickshaw'] ['bus', 'auto rickshaw']
# ['motorcycle', 'bus'] ['dhaka-bound bus', 'hamim poribanhan']
# ['lorry', 'train'] ['lorry']
# ['train', 'bus'] []
# ['auto rickshaw', 'truck'] ['autorickshaw', 'truck', 'auto']
# ['bus', 'other'] ['bike', 'bus']
# ['bus', 'bus'] ['surja paribahan bus', 'shyamoli paribahan bus']
# ['train', 'bus'] ['train', 'ananda poribahan bus']
# ['pedestrian', 'bus'] ['passenger bus', 'dhaka-bound grameen travels bus']
# ['truck', 'bus'] ['dumping truck', 'passenger bus']
# ['truck', 'rickshaw', 'bus', '(truck)'] ['speeding truck', 'rickshaw', 'passenger bus', 'truck']
# ['bus', 'other'] ['passenger bus']
# ['truck'] ['truck']
# ['other'] ['bike', 'two-wheeler']
# ['car', 'train'] ['chattogram-bound subarna express']
# ['van', 'pedestrian'] ['pick-up van', 'pickup van']
# ['bus'] []
# ['microbus', 'lorry'] ['microbus', 'lorry']
# ['truck', 'rickshaw'] ['truck', 'sugar-laden truck', 'battery-run rickshaw']
# ['motorcycle'] ['unknown vehicle']
# ['other', 'truck'] ['truck']
# ['van', 'three-wheeler'] ['three-wheeler', 'chattogram-bound van']
# ['other'] ['motorcycle', 'amanat shah']
# ['train', 'cng'] ['cng-run auto-rickshaw', 'dhaka-bound mail train']
# ['microbus'] ['microbus']
# ['truck', 'truck'] ['truck', 'stone laden truck']
# ['van', 'rickshaw'] ['speeding van']
# ['van', 'other'] ['bike', 'van']
# ['easy-bike'] ['easy-bike']
# ['microbus', 'bike'] ['microbus', 'rooppur ik road']
# ['train', 'train'] ['mail train', 'subarna express train']
# ['bus', 'auto rickshaw'] ['cng-run auto-rickshaw', 'rangpur-bound bus', 'bagura-bound auto-rickshaw']
# ['truck', 'other'] ['speeding truck']
# ['ambulance', 'truck'] ['ambulance', 'fish laden truck']
# ['other', 'van'] ['pickup van', 'battery-operated rickshaw', 'easy bike']
# ['bus', 'car'] ['passenger bus']
# ['truck'] ['jaflong-bound truck']
# ['boat'] ['banglabazar-bound speedboat', 'shimulia ferry ghat', 'sand-laden bulk carrier', 'kathalbari ferry ghat', 'speedboat']
# ['truck', 'cng'] ['cng run auto-rickshaw', 'jaflong-bound stone-laden truck', 'cng- run auto-rickshaw']
# ['launch'] ['ml rabit al hasan', 'oil-laden tanker']
# ['bus', 'microbus'] ['state-run passenger bus', 'microbus']
# ['truck', 'van'] ['pick-up van']
# ['pedestrian', 'train'] ['inter-city train', 'godhuli express']
# ['truck', 'microbus', 'car', '(motorcycle)'] ['truck', 'microbus']
# ['truck', 'motorcycle'] ['truck']
# ['bus', 'truck'] ['bus', 'truck', 'bangabandhu bridge west link highway', 'mymensingh-bound bus']
# ['pedestrian', 'auto rickshaw'] ['auto-rickshaw', 'three-wheeler']
# ['bus'] ['private passenger bus', 'bus']
# ['bus', 'car', 'truck', '(truck)'] ['bus', 'private car', 'dhaka-bound bus', 'cattle- laden truck']
# ['motorcycle', 'truck'] ['truck']
# ['van', 'microbus'] ['pick-up van', 'microbus']
# ['pedestrian'] ['vehicle']
# ['bus', 'auto rickshaw'] ['bus', 'auto-rickshaw', 'beanibazar bound bus']
# ['motorcycle', 'trolley'] ['motorbike', 'trolley']
# ['bus', 'pedestrian'] ['shuktara paribahan bus']
# ['microbus', 'truck'] ['microbus', 'dhaka-khulna highway', 'goods-laden truck']
# ['truck', 'motorcycle'] ['truck', 'thakurgaon-dinajpur road']
# ['microbus'] ['microbus', 'sherpur-bound microbus']
# ['bus', 'human hauler', 'motorcycle'] ['speedy bus']
# [] []
# [] []
# ['cng', 'auto rickshaw'] ['goods-laden truck', 'cng-run auto rickshaw']
# [] []
# ['motorcycle', 'bus'] ['passenger bus']
# ['truck', 'auto rickshaw'] ['truck', 'auto-rickshaw', 'sherpur-dhaka highway']
# ['trolley'] ['trolley', 'shallow-engine driven trolley']
# ['autorickshaw', 'bus'] ['bus', 'sylhet-bholaganj highway']
# ['pedestrian', 'lorry'] ['speedy lorry']
# ['truck', 'pickup'] ['dhaka-bound stone-laden truck', 'narsingdi-bound pick-up']
# ['truck', 'human hauler'] ['truck', 'human-hauler', 'human hauler']
# ['pedestrian'] []
# ['pedestrian', 'train'] ['lalmonirhat bound local train']
# ['van', 'truck'] ['a pickup van', 'truck']
# ['truck', 'pedestrian'] ['brick-laden truck', 'truck']
# ['cng', 'truck'] ['auto-rickshaw', 'jeep']
# ['van', 'motorcycle'] ['covered van', 'motorcycle']
# ['auto rickshaw', 'truck'] ['auto-rickshaw', 'truck']
# ['motorcycle'] ['motorcycle']
# ['boat'] ['tourist boat']
# ['motorcycle', 'truck', 'truck', '(van, microbus, bicycle, trolley, bicycle, truck, rickshaw)'] ['truck', 'motorcycle', 'pickup van', 'stone-laden truck', 'microbus']
# ['car'] ['private car', 'car', 'electric pole']
# ['van', 'motorcycle', 'truck', '(pedestrian, bus, motorcycle, motorcycle, bus)'] ['covered van', 'sand-laden truck', 'bus']
# ['bus', 'van'] ['covered van', '&lsquoena paribahan&rsquo bus']
# ['pedestrian', 'other'] ['cow-laden &lsquonosimon&rsquo']
# ['train', 'motorcycle', 'bus', '(van, auto rickshaw, auto rickshaw, bus, auto rickshaw, truck, motorcycle, trolley, truck, motorcycle, bus)'] ['train', 'bus', 'pick-up van', 'auto-rickshaw']
# ['truck', 'motorcycle'] ['truck']
# ['bus', 'auto rickshaw'] ['bus', 'battery-run auto-rickshaw', 'mymensingh bound bus']
# ['tractor', 'motorcycle'] ['tractor', 'motorcycle']
# ['bus'] ['bus']
# ['van', 'rickshaw'] ['covered van']
# ['train', 'motorcycle'] ['train']
# ['car', 'motorcycle', 'truck'] ['car', 'truck']
# ['car', 'car', 'bus'] ['private car']
# ['pedestrian', 'bus'] ['bus']
# ['tractor'] ['tractor', 'sand-laden tractor']
# ['human hauler', 'motorcycle'] ['human-hauler', 'motorcycle']
# ['pedestrian', 'bus'] ['bus']
# ['ambulance', 'auto rickshaw'] ['ambulance-auto rickshaw', 'ambulance', 'battery-run auto-rickshaw', 'auto-rickshaw']
# ['motorcycle', 'microbus'] ['microbus']
# ['motorcycle', 'pickup'] ['pick up']
# ['pedestrian', 'truck'] ['truck']
# ['van', 'motorcycle'] ['covered van']
# ['van', 'truck'] ['pickup van']
# [] ['faulty vehicles']
# ['microbus', 'bus'] ['dhaka-bound microbus']
# ['truck', 'bus'] ['bogura-dhaka highway', 'potato-laden truck', 'bus']
# ['truck', 'motorcycle'] ['truck', 'chapainawabganj-rajshahi highway']
# ['truck', 'auto rickshaw'] ['truck', 'auto-rickshaw', 'sand laden truck']
# ['three-wheeler'] []
# ['bus', 'motorcycle'] ['bus', 'dhaka-bound bus']
# ['motorcycle', 'truck', 'tractor', '(motorcycle, bus, pedestrian, bus)'] ['truck', 'tractor', 'passenger bus']
# ['bus'] ['mymensingh bound bus', 'dhaka-bound bus', 'oil laden tank lorry']
# ['bus', 'motorcycle', 'power tiller', '(trolley, power tiller, auto rickshaw, bus, pedestrian)'] ['bus', 'power-tiller', 'straw-laden vehicle', 'truck', 'battery-run auto-rickshaw', 'speedy bus']
# ['lorry', 'car', 'car'] ['lorry']
# ['truck', 'three-wheeler', 'car', '(pedestrian, bus, pedestrian, truck, pedestrian, three-wheeler, pedestrian, car, motorcycle, three-wheeler, motorcycle, three-wheeler, pedestrian, bus)'] ['truck', 'three-wheeler', 'dhaka-bound private car', 'bus', 'passenger bus', 'private car']
# ['pedestrian', 'car'] ['private car']
# ['motorcycle', 'motorcycle'] ['two motorcycles', 'netrakona-mohanganj road']
# ['truck', 'pedestrian'] ['speeding truck', 'pickup']
# ['pedestrian', 'truck'] ['mini truck', 'ramu -bound mini truck']
# ['train'] ['moving train']
# ['train'] ['six bogies', 'rangpur express']
# ['train', 'pedestrian'] []
# ['bus'] ['subarno paribahan bus']
# ['train', 'pedestrian'] ['train']
# ['bus', 'motorcycle'] ['bus']
# ['truck', 'motorcycle'] ['truck']
# ['bus', 'motorcycle'] ['motorcycle', 'bus']
# ['motorcycle', 'car'] ['police vehicle', 'motorbike']
# ['motorcycle', 'train'] ['dhaka-bound inter-city egaro sindur express']
# ['bus', 'heavy vehicle'] ['bus', 'heavy vehicle']
# ['bus', 'heavy vehicle'] ['bus', 'another heavy vehicle']
# ['motorcycle', 'truck', 'auto rickshaw', '(pedestrian, pedestrian, easy-bike)'] ['truck', 'battery-run auto-rickshaw', 'auto-rickshaw', 'easy-bike']
# ['train', 'microbus'] ['india-bound freight train', 'microbus']
# ['train', 'pedestrian'] ['khulna-bound &lsquokapatakkha&rsquo train']
# ['train', 'pedestrian'] ['train']
# ['van'] ['kathalbari-bound van']
# ['bus', 'car'] ['aricha-bound bus', 'private car']
# ['pedestrian', 'human hauler'] ['human hauler']
# ['bus', 'autorickshaw'] ['bus', 'cng-run auto-rickshaw', 'auto-rickshaw']
# ['train'] ['panchagarh-bound &lsquouttarbanga mail&rsquo train', 'two bogies of the train']
# ['bus', 'autorickshaw'] ['bus', 'autorickshaw']
# ['tractor', 'pedestrian'] ['tractor']
# [] []
# [] []
# ['motorcycle'] ['motorcycle']
# [] []
# ['bus', 'motorcycle'] ['bus', 'motorcycle', 'truck', 'passenger bus']
# ['bus', 'bus'] ['tekerhat-bound local bus', 'rangpur-bound bus']
# ['bus', 'truck', 'auto-rickshaw'] ['goods-laden truck', 'cng-run auto-rickshaw']
# ['(bus , bus )', '(motorcycle , auto rickshaw)', '(na, na)', '(na, na)'] ['bus', 'gopalganj-bound bus']
# nan []
# ['bus'] ['picnic bus']
# ['bus', 'pedestrian'] ['speedy bus', 'van']
# ['bus', 'microbus'] ['microbus', 'rangpur-bound bus']
# ['motorcycle', 'autorickshaw'] ['motorcycle', 'auto-rickshaw', 'motorbike']
# ['bus'] ['cox&rsquos bazar-bound bus']
# ['truck'] ['dhaka-aricha highway', 'truck']
# ['motorcycle', 'bus'] ['bus', 'truck']
# ['truck'] ['a cattle-laden truck']
# ['bus'] []
# ['bus', 'bus'] []
# ['rickshaw', 'truck', 'car', 'cng'] ['truck', 'cng-run auto-rickshaw']
# [] []
# ['minibus'] ['dhaka bound minibus']
# [] []
# ['motorcycle', 'van'] ['motorcycle', 'covered van']
# ['pickup'] ['pickup van', 'pick-up van', 'cng run auto-rickshaw']
# ['(truck, pick-up)', '(trolley, pedestrian)', '(motorcycle, motorcycle)', '(pick up, na)'] ['truck', 'fish-laden trolley', 'pick-up van']
# ['car', 'bus'] ['baishakhi paribahan bus']
# ['truck'] ['mango-laden truck']
# [] []
# ['truck', 'pedestrian'] ['stone-laden truck']
# ['easy-bike', 'truck'] ['easy-bike', 'cattle-laden truck']
# [] []
# ['bus', 'car', 'auto rickshaw'] ['bus', 'truck', 'coal-laden truck']
# ['truck', 'van'] ['van', 'truck']
# ['truck'] ['truck']
# ['truck', 'train'] ['maitree express', 'sand-laden truck']
# ['truck', 'autorickshaw'] ['truck']
# ['truck', 'pickup'] ['truck', 'dhaka-bound pick-up van', 'pick-up van']
# ['truck', 'pickup'] ['truck', 'pickup']
# ['train', 'human hauler', 'human hauler', 'motorcycle'] ['human hauler']
# ['truck', 'truck'] ['stationary truck', 'dhaka-bound truck', 'stationery truck']
# ['train'] []
# [] []
# ['train'] ['upaban express']
# ['truck', 'motorcycle'] ['truck', 'motorbike']
# ['truck'] ['truck']
# ['bus', 'motorcycle'] ['bus', 'motorbike']
# [] []
# ['truck'] ['cement-laden truck', 'kushtia-bound truck']
# ['truck', 'motorcycle'] ['stone-laden truck']
# ['bus', 'pedestrian'] ['bus']
# ['bus', 'truck'] ['bus', 'dhaka-bound tomato-laden truck']
# ['(truck, bus, microbus)', '(na, microbus, motorcycle)', '(na, na, na)', '(na, na, na)'] ['truck', 'bus', 'microbus']
# ['bus', 'auto rickshaw'] ['bus', 'auto-rickshaw']
# ['bus', 'pickup'] ['pick-up van', 'bus']
# ['car'] ['private car']
# ['bus', 'truck', 'bus', 'truck'] ['dhaka-bound bus', 'truck', 'nilphamari-bound bus']
# [] ['private car', 'gaibandha-bound bus']
# [] []
# ['bus', 'boat'] []
# ['bus', 'car'] ['alam asia paribahan']
# ['motorcycle'] ['motorcycle']
# ['truck'] ['truck']
# ['bus', 'truck'] ['banaful paribahan bus', 'truck']
# ['truck', 'car'] []
# [] ['locally-made motorised vehicles']
# ['bus', 'human hauler'] ['human hauler', 'passenger bus', 'limon paribahan']
# ['bus'] ['passenger bus', 'khulna-bound bus']
# ['train'] ['jayantika express', 'parabat express']
# ['human hauler', 'bus'] ['passenger bus', 'human hauler']
# ['human hauler', 'bus'] ['human hauler', 'passenger bus']
# ['bus', 'microbus'] ['microbus', 'passenger bus', 'hiace car']
# [] []
# [] []
# ['(microbus, bus)', '(truck, pedestrian)', '(motorcycle, na)', '(na, na)'] ['microbus', 'truck', 'motorcycle', 'ananda paribahan']
# [] []
# nan ['covered van', 'cng run auto-rickshaw', 'stationary auto-rickshaw']
# ['car', 'car'] ['uber car', 'private car']
# [] []
# ['bus'] ['mollarhat-bound bus']
# ['car', 'pedestrian', 'auto rickshaw'] ['private car', 'cng autorick']
# ['bus'] ['sherpur-bound bus']
# ['bus', 'pickup'] ['passenger bus', 'pick-up van']
# ['civilian lorry'] ['civilian lorry']
# ['minibus'] ['staff minibus']
# ['train', 'bicycle'] ['bicycle']
# ['(truck, car)', '(motorcycle, na)', '(na, na)', '(na, na)'] ['truck']
# ['train', 'pedestrian'] ['train']
# [] []
# ['bus'] ['ramganj-bound bus']
# ['trolley'] ['trolley']
# ['(truck, bus, motorbike)', '(human hauler, other, other)', '(na, na, na)', '(na, na, na)'] ['truck', 'human hauler', 'khulna-mongla highway', 'mongla-bound truck', 'motorbike']
# ['van'] ['pick-up van']
# ['truck', 'human hauler'] ['truck', 'human hauler', 'khulna-mongla highway', 'mongla-bound truck']
# [] []
# ['(car, cng, bus, truck)', '(pedestrian, na, pedestrian, pedestrian)', '(na, na, na, na)', '(na, na, na, na)'] ['private car', 'cng autorickshaw']
# nan ['covered van']
# ['truck', 'lorry'] ['sand-laden truck', 'lorry']
# ['microbus'] ['microbus', 'micro-bus']
# ['car', 'motorcycle'] ['private car', 'motorcycle']
# ['bus', 'rickshaw'] ['rickshaw van', 'passenger bus', 'battery-run rickshaw van']
# nan []
# ['bus', 'car, rickshaw'] ['two buses', 'private car', 'two rickshaws']
# ['motorcycle', 'pedestrian'] ['motorcycle']
# [] []
# nan []
# ['truck', 'motorcycle'] ['speeding truck']
# ['auto rickshaw', 'train'] ['auto-rickshaw', 'locomotive', 'auto-auto rickshaw']
# ['(bus, ambulance)', '(human hauler, van)', '(na, na)', '(na, na)'] ['bus', 'human hauler', 'covered van']
# ['truck', 'pedestrian'] ['truck']
# ['bus'] ['mh 196', 'bus']
# ['train'] ['train bogie']
# ['bus', 'motorcycle'] ['bus', 'motorcycle']
# ['human hauler', 'truck'] ['human hauler', 'truck', 'sand-laden truck']
# ['bus'] ['burimari-bound &lsquobarkat enterprise&rsquo bus']
# ['bus'] ['joupurhat-bound bus']
# ['truck', 'truck'] ['sand-laden truck', 'potato-laden truck']
# ['truck'] ['truck']
# ['(human hauler, bus)', '(na, pedestrian)', '(na, na)', '(na, na)'] ['cattle-laden human hauler', 'bus']
# ['motorcycle', 'truck'] ['shariatpur-bound motorbike', 'stationary truck']
# ['bus', 'rickshaw'] ['bus']
# nan ['auto-rickshaw', 'jeep']
# ['bus', 'microbus'] ['microbus']
# ['(bus, van, van, tractor, trucks, auto-rickshaw)'] ['passenger bus', 'goods-laden pick-up van', 'covered van', 'tractor', 'auto-rickshaw', 'sand-laden truck']
# ['(bus, microbus, bus, truck, human hauler, car)'] ['passenger bus', 'microbus']
# nan []
# ['truck', 'car'] ['truck', 'private car']
# nan []
# nan []
# nan []
# nan ['motorcycle', 'bus', 'auto-rickshaw']
# nan ['private car']
# nan ['covered van']
# ['bus', 'microbus'] ['bus', 'microbus', 'chattogram-cox&rsquos bazar highway', 'relax paribahan']
# ['human hauler', 'tractor'] ['human hauler', 'tractor']
# ['motorcycle', 'auto-rickshaw'] ['motorcycle', 'auto-rickshaw']
# ['bus', 'motorbike'] ['bus', 'motorbike', 'dhaka-chattogram highway']
# ['car'] ['car']
# ['bus'] []
# ['train', 'motorcycle'] []
# nan ['covered van', 'thakurgaon-bound bus']
# ['bus'] []
# nan ['tractor', 'truck']
# ['bus'] ['bus']
# nan ['truck', 'auto-rickshaw', 'covered-van', 'thakurgaon-bound bus', 'pickup van']
# ['bus'] ['bus']
# ['bus', 'van'] ['bus', 'van']
# ['motorcycle'] ['motorbike']
# nan []
# ['truck', 'motorcycle', 'bus'] ['truck', 'bus']
# ['bus', 'bus'] []
# ['train'] ['laksam-bound demu train']
# ['bus', 'truck'] ['picnic bus', 'stationary truck']
# ['car', 'van', 'auto rickshaw'] ['auto-rickshaw', 'private car', 'covered van']
# ['bus', 'three-wheeler'] ['bus', 'three-wheeler']
# ['bus', 'human-hauler'] ['bus', 'human-hauler', 'patuakhali-bound bus', 'human hauler']
# ['van'] ['pick-up van']
# nan ['rickshaw']
# ['bus', 'train', 'car'] ['chattogram- bound train', 'picnic bus']
# ['truck'] ['truck']
# ['train'] ['commuter train']
# ['tractor'] ['tractor']
# ['bus', 'bicycle'] ['bus', 'dhaka-bound bus', 'bi-cycle']
# nan ['bus', 'truck', 'akhaura-chandura road', 'motorcycle', 'covered van', 'dhaka-chittagong highway', 'dhaka-khulna highway']
# ['van', 'pedestrian'] ['covered van', 'dhaka-chittagong highway']
# nan ['covered van']
# ['vehicle', 'motorbike'] ['unknown vehicle']
# ['(van, bus, auto-rickshaw, motorcycle)'] ['covered van', 'bus', 'auto-rickshaw']
# nan ['mymensingh-bound train']
# ['bus', 'truck'] ['dhaka-chattogram highway', 'fatikchhari maizbhandar darbar sharif']
# ['bus'] ['picnic bus']
# nan ['private car', 'covered van', 'picnic bus']
# nan ['truck']
# nan []
# ['car', 'van'] ['private car', 'covered van']
# nan ['rod-laden truck', 'truck']
# ['truck'] ['speedy truck']
# [] ['motorised vehicles']
# ['bus', 'motorcycle'] ['bus', 'motorcycle']
# ['motorcycle'] ['motorcycle']
# nan ['truck']
# ['truck', 'microbus'] ['truck', 'microbus', 'bagerhat-bound microbus']
# ['motorcycle', 'van'] ['covered van']
# ['truck', 'van'] ['covered van']
# nan ['human hauler', 'cng-run auto-rickshaw']
# nan ['goods-laden truck']
# ['bus'] ['bus']
# ['microbus', 'bus'] ['microbus', 'bus', 'saudia paribahan']
# ['car'] ['private car']
# ['bus'] []
# nan []
# ['motorbike', 'truck'] ['truck', 'motorbike']
# ['truck'] ['brick-laden truck']
# ['truck'] ['coal-laden truck']
# [] ['vehicles without fitness']
# nan ['coal-laden truck']
# nan ['truck', 'motorcycle']
# ['truck', 'motorbike'] ['truck']
# ['car'] ['private car', 'dhaka-bound car']
# ['train'] ['train']
# nan ['truck', 'sonapur-bound truck']
# ['truck'] ['coal-laden truck']
# ['truck', 'cng'] ['truck', 'cng-run auto-rickshaw', 'goods-laden truck']
# ['rickshaw', 'bus', 'car'] ['bus', 'auto-rickshaw']
# ['bus', 'van'] ['dhaka-bound green line bus', 'covered-van', 'private car', 'cdm paribahan bus']
# nan ['a private car']
# ['van'] ['covered van']
# nan []
# nan ['train']
# ['bus', 'motorcycle'] ['bus']
# ['autorickshaw', 'bus'] ['auto rickshaw', 'noakhali bound bus']
# ['human hauler', 'pedestrian'] ['human hauler', 'feni-bound bus', 'sugandha paribahan']
# ['van', 'motorcycle'] ['engine-run van', 'palua', 'van']
# nan []
# ['autorickshaw', 'human hauler'] ['auto-rickshaw', 'human hauler']
# ['bus', 'autorickshaw'] ['passenger bus', 'auto-rickshaw', 'netrakona bound bus', 'minibus']
# nan []
# ['truck'] ['sand-laden truck']
# ['bus'] ['gazipur-bound bus']
# ['bus'] ['gazipur-bound bus']
# ['truck', 'rickshaw'] ['truck', 'sand-laden truck']
# ['truck', 'van'] ['pick-up van', 'stone-laden truck', 'dhaka-bound van']
# nan []
# ['bus', 'bus'] []
# ['truck', 'motorcycle'] ['truck', 'bus', 'auto-rickshaw', 'three-wheeler', 'three wheeler']
# ['bus'] ['domar-bound bus']
# ['human hauler', 'motorcycle'] ['human hauler', 'motorcycle']
# ['truck'] ['truck']
# ['tractor', 'car', 'motorcycle'] ['tractor']
# ['motorcycle'] []
# [] ['goran road no. 8']
# ['truck', 'microbus'] ['truck', 'microbus']
# ['bus', 'car'] ['passenger bus']
# ['bus', 'human-hauler'] ['human-hauler', 'bus', 'mahendra']
# ['bus', 'motorcycle'] []
# ['motorcycle', 'truck', 'bus'] ['human hauler']
# ['van', 'truck'] ['van', 'truck']
# nan ['khulna-bound inter-city chitra express train']
# ['microbus', 'van'] ['microbus', 'covered van']
# ['bus'] ['mongla-bound bus']
# ['van', 'truck', 'bus'] ['pick-up van']
# ['truck', 'bus'] ['&lsquoemad paribahan&rsquo bus', '&lsquoeagle paribahan&rsquo bus', 'pickup']
# [] []
# ['truck', 'car'] ['truck', 'private car', 'shimulia ghat-bound truck']
# ['van'] ['covered van']
# ['bus', 'covered van', 'truck'] ['covered van', 'goods-laden truck', 'bus']
# ['bus', 'auto-rickshaw'] ['bus', 'auto-rickshaw', 'dhaka-sylhet highway']
# ['bus', 'motorcycle'] ['manikganj bound passenger bus']
# ['bus', 'car', 'rickshaw'] ['brtc bus', 'auto-rickshaw']
# ['covered van', 'motorcycle'] ['covered van']
# nan ['mohanganj-bound train']
# nan ['15 vehicles']
# ['bus'] ['benapole-bound bus']
# ['bus', 'van', 'truck', 'trolley'] ['northern region-bound iron rod-laden truck', 'brick-laden trolley']
# ['truck'] ['wooden log-laden truck']
# ['train'] ['khulna-bound commuter train', 'mymensingh-bound commuter train']
# ['bus', 'human hauler'] ['bus', 'human hauler', 'leguna']
# ['bus', 'cng', 'car', 'rickshaw'] ['bus', 'cng-run auto-rickshaw', 'auto-rickshaw']
# ['bus'] ['bhairab-bound &lsquoroyal paribahan&rsquo bus']
# ['trolley', 'van', 'truck'] ['trolley', 'van', 'brick-laden trolley', 'northern region-bound iron rod-laden truck']
# ['bus', 'bus', 'truck'] ['speeding truck']
# ['train', 'bus'] ['local bus']
# ['bus', 'truck', 'motorbike', 'human hauler'] ['bus', 'truck', 'cement-laden truck']
# nan ['munshiganj-bound truck']
# ['motorcycle', 'truck'] ['motorcycle', 'oil-laden truck']
# ['bus'] ['sylhet-bound &lsquosylhet express']
# ['train', 'motorcycle'] ['khulna-bound train', 'motorcycle']
# ['bus'] ['bus']
# ['human hauler'] ['human hauler']
# ['truck', 'motorcycle', 'bus'] ['truck', 'motorcycle', 'bus']
# ['bus', 'van', 'truck'] ['truck', 'covered van', 'dhaka-chattogram highway', 'chattogram-bound truck', 'bus', 'khuln-satkhira highway', 'satkhira-bound truck']
# ['truck', 'easy-bike', 'motorcycle'] ['truck', 'battery-run easy-bike', 'easy bike']
# nan ['truck']
# ['ambulance'] ['ambulance']
# ['bus'] ['chapainawabganj-bound bus']
# ['pick-up van'] ['pick-up van']
# ['motorcycle'] ['motorcycle']
# ['motorbike', 'lorry'] ['speeding lorry', 'lorry']
# ['bus'] ['bus']
# ['truck', 'van'] ['goods-laden truck', 'engine-run van']
# ['bus', 'trolley'] ['bus', 'trolley', 'dhaka-mawa highway']
# ['motorcycle'] ['speeding motorcycle']
# ['bus', 'bus'] ['two buses']
# ['van', 'truck'] ['truck', 'van']
# nan ['cng-run auto-rickshaw', 'cng auto-rickshaw']
# ['truck', 'motorbike'] ['speeding truck']
# ['bus', 'bicycle'] ['bus']
# ['unknown vehicle', 'auto-rickshaw'] ['unknown vehicle', 'cng run auto-rickshaw', 'northern districts- bound vehicle']
# ['rickshaw', 'truck', 'car'] ['speeding lorry', 'oil-laden lorry']
# ['truck'] ['truck']
# ['truck', 'motorcycle'] ['natore-bound goods-laden truck']
# ['motorcycle', 'truck'] ['truck']
# ['truck'] ['mohakhali-bound pickup']
# ['trolley', 'human hauler'] ['trolley', 'human hauler']
# [] []
# ['bus'] ['bus', 'human hauler']
# ['truck', 'car', 'van'] ['covered van', 'container from a lorry', 'lorry']
# nan []
# ['autorickshaw', 'roller'] ['cng autorickshaw']
# ['train'] ['engine compartment', 'dhaka-bound engine compartment']
# [] []
# ['truck'] ['truck']
# ['bus'] ['bus', '&lsquoena paribahan&rsquo']
# ['bus', 'truck'] ['truck', 'bus']
# ['motorcycle', 'truck'] ['sand-laden truck']
# ['bus', 'truck'] ['tentulia-bound bus', 'truck carrying electric poles', 'truck']
# ['private car'] ['private car']
# ['train', 'other'] ['noakhali-bound train']
# ['bus', 'truck'] ['tentulia-bound bus', 'truck carrying electric poles']
# ['motorcycle', 'auto-rickshaw'] ['motorcycle', 'cng-run auto-rickshaw', 'auto rickshaw']
# ['truck', 'truck'] ['truck']
# ['bus', 'motorbike'] ['bus']
# nan []
# ['motorcycle', 'van'] ['covered van', 'chattogram bound subarna express train']
# ['motorbike'] []
# ['bus', 'bus'] ['dhaka-bound bus']
# nan ['aircraft']
# nan ['container']
# ['bus'] ['jabal-e-noor', 'shahadat hossain', 'jahangir alam', 'jabal-e-noor paribahan']
# nan []
# ['bus', 'bus'] ['trans silva paribahan']
# ['van', 'auto-rickshaw'] ['covered van', 'auto-rickshaw']
# nan []
# ['bus'] ['bus']
# ['microbus', 'motorcycle', 'van'] ['microbus', 'motorcycle', 'van']
# ['bus', 'bus'] ['&lsquojabal-e-noor paribahan&rsquo bus', 'jahangir alam']
# nan []
# ['motorbike', 'auto-rickshaw', 'tractor'] ['tractor', 'cng-run auto-rickshaw']
# ['tractor'] ['tractor']
# ['bus', 'auto-rickshaw'] ['bus', 'cng-run auto-rickshaw']
# nan ['human-hauler', 'bhatiapara-bound shuttle train', 'three-wheeler']
# ['truck'] ['dhaka-tangail highway', 'joypurhat-bound truck']
# nan []
# ['train'] []
# nan ['train']
# [] []
# ['motorcycle', 'human hauler'] ['human hauler']
# ['bus'] ['jashore-bound bus']
# ['truck', 'rickshaw-van'] ['truck', 'goods-laden truck', 'rickshaw van']
# ['bus'] []
# ['pick-up van'] ['pick-up van', 'dhaka-khulna highway']
# ['truck', 'human hauler'] ['truck', 'human hauler', 'magura-bound truck']
# ['tractor'] ['tractor', 'sand-laden tractor']
# ['private car'] ['private car', 'khalukhai&ndashbound car']
# ['bus'] ['bus']
# ['truck', 'motorbike'] ['truck']
# ['tractor'] ['tractor']
# ['motorcycle'] ['motorcycle']
# ['human-hauler'] ['human- hauler', 'magura-jashore highway', 'nasimon']
# ['boat'] ['trawler', 'sand-laden cargo']
# ['truck', 'auto rickshaw'] ['speeding truck', 'battery-run auto rickshaw', 'dhaka bound truck']
# ['auto-rickshaw'] ['cng-run auto-rickshaw']
# ['ambulance', 'truck', 'auto-rickshaw'] ['ambulance', 'truck', 'kushtia-bound ambulance', 'stationary cng- run auto-rickshaw']
# ['bus', 'human-hauler'] ['dhaka-bound bus', 'shaymoli paribahan', 'human-hauler']
# ['motorbike', 'human-hauler'] ['bhutbhuti']
# nan []
# nan []
# nan ['train']
# nan ['dhaka-bound container train']
# nan ['rail truck', 'rajshahi-bound &lsquosagordari&rsquo train']
# ['pick-up van', 'rickshaw'] ['pick-up van']
# nan []
# nan ['four wagons']
# [] []
# ['motorbike', 'bus'] ['bus']
# ['bus'] ['bus']
# ['motorcycle', 'car'] ['car', 'motorcycle']
# ['truck', 'sports utility vehicle'] ['cement-laden truck', 'jeep']
# ['bus'] ['bus']
# ['bus', 'motorcycle'] ['speedy bus']
# ['truck'] ['truck', 'bogura-bound iron rod-laden truck']
# ['bus', 'motorcycle'] ['bus']
# ['truck', 'autorickshaw'] ['speeding truck', 'coal-laden dhaka-bound truck']
# ['motorcycle'] ['motorcycle', 'motorbike']
# ['truck'] ['truck', 'dhaka-aricha highway']
# ['bus', 'auto-rickshaw'] ['bus', 'auto-rickshaw', 'dhaka-bound bus']
# ['bus'] ['bus']
# ['minibus', 'motorcycle'] ['minibus']
# nan ['container train']
# ['truck', 'motorcycle'] ['truck', 'motorcycle']
# ['car', 'microbus', 'auto-rickshaw'] ['car', 'microbus', 'auto-rickshaw']
# nan []
# ['bus', 'bus'] ['greenline paribahan&rsquo bus', 'a &lsquodidar paribahan&rsquo bus']
# nan ['container train']
# nan []
# ['train'] ['train']
# ['truck', 'van', 'motorcycle'] ['chattogram-bound poultry-laden covered van', 'truck', 'motorcycle', 'motorbike']
# ['auto-rickshaw', 'bus'] ['cng-run auto-rickshaw', 'auto-rickshaw', 'speeding bus']
# ['bus', 'bus'] ['dhaka-bound bus']
# ['bus', 'bus'] ['bus']
# ['bus', 'auto-rickshaw'] ['sonamukhi-bound bus', 'auto-rickshaw']
# ['car', 'microbus'] ['a microbus', 'microbus']
# ['truck'] ['biswambarpur-bound truck', 'truck']
# ['bus'] ['&lsquojabal-e-noor paribahan&rsquo bus', 'jahangir alam']
# [] []
# ['train', 'other'] ['dhaka-bound &lsquoupoban express']
# nan []
# ['van', 'human hauler'] ['covered van', 'human hauler']
# ['truck', 'microbus'] ['truck', 'microbus']
# ['van', 'van'] ['two covered vans']
# ['bus', 'human-hauler'] ['leguna', 'dhaka-bound bus']
# ['bus'] ['dhaka-aricha highway', 'paturia-bound &lsquogreen bangla&rsquo bus']
# ['bus'] ['dhaka-panchagarh highway', 'inter-district bus', 'auto-rickshaw', 'human hauler']
# ['auto-rickshaw', 'truck'] ['cng-run auto-rickshaw', 'truck', 'tractor', 'auto-rickshaw']
# nan ['train']
# ['bus', 'bus'] ['&lsquojabal-e-noor paribahan&rsquo bus']
# ['boat'] ['barishal-bound launch', 'mv sharuk-1']
# ['bus'] ['bus']
# [] []
# ['tractor', 'motorbike'] ['tractor']
# ['auto-rickshaw', 'van'] ['cng run auto-rickshaw', 'pick-van', 'pick-up van']
# ['truck', 'human-hauler'] ['truck', 'human-hauler']
# ['bus', 'other', 'pedestrian'] ['ilisha paribahan']
# ['human hauler', 'motor-cycle'] ['human hauler', 'motor-cycle', 'motorcycle']
# ['bus', 'human-hauler'] ['bogura-bound bus', 'challenger paribahan', 'human-hauler']
# ['pick-up', 'truck'] ['pick-up', 'truck', 'dhaka-aricha highway', 'dhaka-bound pick-up']
# ['microbus'] ['microbus']
# ['human hauler', 'bus'] ['human hauler', 'dhaka-mymensingh highway', 'leguna']
# ['bus', '(bus, van)'] ['rangpur-bound bus', 'bus', 'covered van']
# nan []
# ['bus'] ['&lsquojabal-e-noor paribahan&rsquo bus', 'jahangir alam']
# nan []
# ['bus', 'bus'] ['brtc bus']
# nan []
# ['train', 'bus', '0', '0'] ['khagrachhari-bound bus']
# nan ['two-stroke auto-rickshaws', 'double-decker buses']
# ['motorcycle', 'bus', 'car'] ['bus', 'dhaka metro ba-14-6828']
# ['bus', 'tractor'] ['tractor', 'dhaka-bound bus', 'darbar paribahan']
# ['car'] ['dhaka-mymensingh highway']
# nan ['ekota express']
# ['bus'] ['bus', 'passenger bus', 'barguna-barishal regional highway', 'cement laden truck', 'cng-run auto-rickshaw']
# ['bus', 'autorickshaw'] ['bus', 'cng-run auto-rickshaw', 'cng- run auto-rickshaw']
# ['bus', 'auto-rickshaw'] ['bus', 'cng-run auto-rickshaw', 'auto-rickshaw']
# ['bus', 'motorcycle'] ['bus', 'dhaka-sylhet highway', 'sylhet-bound bus', 'motorcycle']
# [] ['13 vehicles']
# ['train'] []
# ['motorcycle', 'bus'] ['bus', 'cng-run auto-rickshaw']
# ['van', 'truck'] ['pick-up van']
# ['bus', 'motorcycle'] ['bus', 'motorcycle']
# nan ['three-wheeled vehicles']
# nan []
# ['bus', 'human hauler'] ['&lsquochallenger paribahan&rsquo', 'human-hauler']
# ['van, motorbike)', 'motorbike'] ['covered van', 'unknown vehicle']
# ['pedestrian', 'bus'] ['khagrachhari-bound tourist bus']
# [] []
# ['auto-bike'] ['battery-run auto-bike', 'auto-bike']
# ['bus', 'human hauler'] ['human hauler', 'bus']
# ['train', 'bus'] ['jabal-e-noorparibahan', 'jabal-e-noor']
# nan []
# ['bus', 'human hauler'] ['human hauler', 'dhaka bound bus', 'ena paribahan']
# ['truck', 'van'] ['paddy-laden truck', 'mango-laden van']
# ['auto-bike'] ['battery-run auto-bike', 'auto-bike']
# ['bus', 'auto-rickshaw'] ['bus', 'auto-rickshaw', 'rangpur-dinajpur highway', 'thakurgaon-bound bus']
# [] []
# ['bus'] []
# nan ['truck', 'microbus']
# ['bus', 'lorry'] ['bus', 'oil-laden lorry']
# nan []
# Correct vehicles: 576.1666666666666/864 (66.69%)

# %% [markdown]
# ### Score on Casualties

# %%
total = len(joined_df)
correct = 0

for index, row in joined_df.iterrows():
    expected = row["expectedCasualties"]
    
    if pd.isna(expected) and row["casualties"] == 0:
        correct += 1
        continue
    
    if type(expected) is float:
        if math.isnan(expected) and row["casualties"] == 0:
            correct += 1    
        continue
    
    try:
        expected = int(row['expectedCasualties'].replace(">", "").replace("<", ""))
    except Exception as e:
        continue
    
    try:
        actual = word2number.w2n.word_to_num(row["casualties"])
    except ValueError:
        actual = 0

    if expected == actual:
        correct += 1

print(f"Correct casualties: {correct}/{total} ({correct/total*100:.2f}%)")
# Out:
# Correct casualties: 87/864 (10.07%)

# %% [markdown]
# ### Score on date

# %%
from dateutil.parser import parse

total = len(joined_df)
correct = 0

day_mapping = {"Monday": 0, "Tuesday": 1, "Wednesday": 2, "Thursday": 3, "Friday": 4, "Saturday": 5, "Sunday": 6}

for index, row in joined_df.iterrows():
    if type(row['expectedDate']) != str:
        continue
    if type(row['date']) != str:
        continue

    try:
        expectedDate = parse(row['expectedDate'].replace("<", "").replace(">", "")).date()
        actualDate = parse(row['date']).date()
        if expectedDate == actualDate:
            correct += 1
        elif abs((expectedDate - actualDate).days) < 7:
            expectedDay = day_mapping[row["expectedDayOfWeek"].replace("<", "").replace(">", "")]
            actualDay = parse(row['date']).weekday()   
            if expectedDay == actualDay:
                correct += 0.75
    except Exception as e:
        continue
        # print(f"Error: {e}")
        # print(f"Row: {row}")
        # print(f"Index: {index}")

print(f"Correct dates: {correct}/{total} ({correct/total*100:.2f}%)")
# Out:
# Correct dates: 460.5/864 (53.30%)

# %% [markdown]
# ### Score on place

# %%
total = len(joined_df)
correct = 0

for index, row in joined_df.iterrows():
    if type(row['expectedPlace']) == str and row['expectedPlace'].replace(">", "").replace("<", "").lower() == row["place"]:
        correct += 1
    else:
        #print(row['expectedPlace'], row["place"])
        pass

print(f"Correct place: {correct}/{total} ({correct/total*100:.2f}%)")
# Out:
# Correct place: 343/864 (39.70%)
